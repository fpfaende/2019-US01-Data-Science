# %%
import pandas as pd

# %%
df = pd.read_pickle('savedDF.pickle')
df.head()
# Out:
#   Country (according to CN Gov): Date of research inquiry  \
# 1                    Afghanistan                      NaT
# 2                        Albania                      NaT
# 3                        Armenia                      NaT
# 4                     Azerbaijan                      NaT
# 5                        Bahrain                      NaT
#
#    HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#    Heritage Foundation Index of Economic Freedom (Global Ranking)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Bertelsmann Transformation index (BTI)  \
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
#
#    Bertelsmann Transformation index (BTI) - Ranking  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#   IMF WB\nCustoms and other import duties (% of tax revenue) 2016  \
# 1                                            35.2031
# 2                                            2.21646
# 3                                            6.27539
# 4                                            7.57185
# 5                                            27.3861
#
#   WB IMF Non-performing loans to total gross loans ratio (%)  \
# 1                                            12.2018
# 2                                            13.2325
# 3                                            5.43232
# 4                                                 NA
# 5                                                 NA
#
#   Moody's Socvereign Ratings List S&P Sovereign Ratings List  ...  \
# 1                             NaN                        NaN  ...
# 2                             NaN                        NaN  ...
# 3                             NaN                        NaN  ...
# 4                             NaN                        NaN  ...
# 5                             NaN                        NaN  ...
#
#   WB Cost of Starting a Business  \
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
#
#   WB Ease of Doing Business Index (1 = most business-friendly regulations)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   WB Logistics Performance Index (LPI) (range: 1-5)   \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   IFDI Net Inflows (% of GDP) ED National Electric Power Consumption TwH  \
# 1                    0.718898                                        NaN
# 2                     8.01551                                        NaN
# 3                     2.04411                                        NaN
# 4                     2.98895                                        NaN
# 5                     4.01407                                        NaN
#
#   WHO Current Health Expenditure p.c., PPP USD  \
# 1                                      162.781
# 2                                      759.667
# 3                                      876.857
# 4                                      1193.06
# 5                                       1866.3
#
#    WB Research Expenditure % of GDP  WIPO Trademark applications  \
# 1                                NA                           NA
# 2                           0.15412                         1232
# 3                            0.2277                         2685
# 4                           0.18521                         2817
# 5                           0.10116                          253
#
#    WIPO Patent Applications  isocode
# 1                        NA      AFG
# 2                        14      ALB
# 3                       107      ARM
# 4                       144      AZE
# 5                         8      BHR
#
# [5 rows x 44 columns]

# %%
bti_df = pd.read_csv('data-BTI-2006-2018.csv')
bti_df[bti_df['year'] == 2018]
bti_df[bti_df['country_code'] == 'BRN']
# Out:
# Empty DataFrame
# Columns: [country, country_code, year, region, rank_stat_ind, stat_ind, rank_dem_stat, dem_stat, stateness, monopoly, identity, no_dogmas, admin, pol_part, elect, power, assembly, express, ruleoflaw, separation, judiciary, prosecution, civ_rights, stab_dem, perf_dem, com_dem, integ, party_sys, int_group, approv_dem, soc_cap, rank_econ_stat, econ_stat, level_development, barriers, market, compet, anti_monop, for_trade, bank, stab_econ, infl, macro_stab, priv_prop, prop_rights, priv_ent, welfare, safety_nets, equal, perf_econ, output, sustain, envir, edu, rank_gov_ind, gov_ind, level_diff, constr, civil_trad, conflict_intens, GNI, UN_edu, state_rol, gov_perf, steering, priority, implement, learning, efficiency, assets, coord, anti_corrupt, consens, goals, veto, cleavage, civil_part, recon, int_coop, use_support, cred, reg_coop, trend_dem, trend_econ, trend_gov, core_stateness, state_failure, pol_sys, cat_stat_ind, cat_dem_stat, cat_trend_dem, cat_econ_stat, cat_trend_econ, cat_gov_ind, cat_trend_gov, cat_level_diff, stateness_cat, pol_part_cat, ruleoflaw_cat, stab_dem_cat, ...]
# Index: []
#
# [0 rows x 113 columns]

# %%
bti_2018 = bti_df[bti_df['year'] == 2018]
for index, isocode in df.isocode.iteritems():
    try:
        ind = bti_2018[bti_2018['country_code']==isocode]['stat_ind']
        rank = bti_2018[bti_2018['country_code']==isocode]['rank_stat_ind']
        df.at[index,'Bertelsmann Transformation index (BTI)'] = ind
        df.at[index,'Bertelsmann Transformation index (BTI) - Ranking'] = rank
    except ValueError:
        print('[critical]:no data for',isocode)
        continue
df[['Country (according to CN Gov):','Bertelsmann Transformation index (BTI)','Bertelsmann Transformation index (BTI) - Ranking' ]]
# Out:
# [critical]:no data for BRN
# [critical]:no data for TLS
# [critical]:no data for FRA
# [critical]:no data for DEU
# [critical]:no data for IOT
# [critical]:no data for ISR
# [critical]:no data for MDV
# [critical]:no data for ROU
# [critical]:no data for GBR
# [critical]:no data for USA
#         Country (according to CN Gov):  \
# 1                          Afghanistan
# 2                              Albania
# 3                              Armenia
# 4                           Azerbaijan
# 5                              Bahrain
# ..                                 ...
# 64  United States of America (Not BRI)
# 65                             Ukraine
# 66                          Uzbekistan
# 67                             Vietnam
# 68                               Yemen
#
#     Bertelsmann Transformation index (BTI)  \
# 1                                 2.954762
# 2                                 6.828571
# 3                                 5.576190
# 4                                 4.127381
# 5                                 4.616667
# ..                                     ...
# 64                                     NaN
# 65                                6.539286
# 66                                3.726191
# 67                                4.407143
# 68                                1.721429
#
#     Bertelsmann Transformation index (BTI) - Ranking
# 1                                              121.0
# 2                                               30.0
# 3                                               61.0
# 4                                              100.0
# 5                                               89.0
# ..                                               ...
# 64                                               NaN
# 65                                              36.0
# 66                                             108.0
# 67                                              94.0
# 68                                             127.0
#
# [68 rows x 3 columns]

# %%
cpi_df = pd.read_excel('data-CPI-2018.xlsx', header=2)
cpi_df.head()
cpi_df.columns
# Out:
# Index(['Country', 'ISO3', 'Region', 'CPI Score 2018', 'Rank ',
#        'Standard error', 'Number of sources', 'Upper CI', 'Lower CI ',
#        'African Development Bank CPIA',
#        'Bertelsmann Foundation Sustainable Governance Index',
#        'Bertelsmann Foundation Transformation Index',
#        'Economist Intelligence Unit Country Ratings',
#        'Freedom House Nations in Transit Ratings',
#        'Global Insight Country Risk Ratings',
#        'IMD World Competitiveness Yearbook', 'PERC Asia Risk Guide',
#        'PRS International Country Risk Guide', 'World Bank CPIA',
#        'World Economic Forum EOS', 'World Justice Project Rule of Law Index',
#        'Varieties of Democracy Project'],
#       dtype='object')

# %%
for index, isocode in df.isocode.iteritems():
    try:
        ind = cpi_df[cpi_df['ISO3']==isocode]['CPI Score 2018']
        rank = cpi_df[cpi_df['ISO3']==isocode]['Rank ']
        df.at[index,'TI Corruption Perception Index'] = ind
        df.at[index,'TI Corruption Perception Index - Ranking'] = rank
    except ValueError:
        print('[critical]:no data for',isocode)
        continue
# Out:
# [critical]:no data for IOT

# %%
heritage_df = pd.read_excel('data-heritage-2019.xls')

# %%
for index, name in df['Country (according to CN Gov):'].iteritems():
    cleaned_name = name.split('(')[0].strip()
    if cleaned_name == 'Thailiand':
        cleaned_name = 'Thailand'
    elif cleaned_name == 'The United Arab Emirates':
        cleaned_name = 'United Arab Emirates'
    elif cleaned_name == 'Brunei':
        cleaned_name = 'Brunei Darussalam'
    elif cleaned_name == 'Myanmar':
        cleaned_name = 'Burma'
    elif cleaned_name == 'East Timor':
        cleaned_name = 'Timor-Leste'
    elif cleaned_name == 'Kyrgyzstan':
        cleaned_name = 'Kyrgyz Republic'
    elif cleaned_name == 'United States of America':
        cleaned_name = 'United States'
    
    
    try:
        ind = heritage_df[heritage_df['Country Name']==cleaned_name]['2019 Score']
        rank = heritage_df[heritage_df['Country Name']==cleaned_name]['World Rank']
        df.at[index,'HF Index of Economic Freedom (Scale: 1-100)'] = ind
        df.at[index,'Heritage Foundation Index of Economic Freedom (Global Ranking)'] = rank
    except ValueError:
        print('[critical]:no data for',cleaned_name)
        continue

# %%
df.describe()
# Out:
#        HF Index of Economic Freedom (Scale: 1-100)  \
# count                                    65.000000
# mean                                     63.170769
# std                                       8.686425
# min                                      44.200000
# 25%                                      55.600000
# 50%                                      63.800000
# 75%                                      68.300000
# max                                      89.400000
#
#        Heritage Foundation Index of Economic Freedom (Global Ranking)  \
# count                                          65.000000
# mean                                           79.446154
# std                                            46.201674
# min                                             2.000000
# 25%                                            43.000000
# 50%                                            71.000000
# 75%                                           121.000000
# max                                           172.000000
#
#        Bertelsmann Transformation index (BTI)  \
# count                               58.000000
# mean                                 5.686618
# std                                  1.899715
# min                                  1.571429
# 25%                                  4.310715
# 50%                                  5.745833
# 75%                                  6.724108
# max                                  9.521429
#
#        Bertelsmann Transformation index (BTI) - Ranking  \
# count                                         58.000000
# mean                                          62.637931
# std                                           38.300611
# min                                            1.000000
# 25%                                           31.500000
# 50%                                           58.000000
# 75%                                           95.500000
# max                                          128.000000
#
#        TI Corruption Perception Index  \
# count                       67.000000
# mean                        42.537313
# std                         17.165265
# min                         13.000000
# 25%                         31.000000
# 50%                         38.000000
# 75%                         55.000000
# max                         85.000000
#
#        TI Corruption Perception Index - Ranking       BRI GDP  BRI GDP p.c.  \
# count                                 67.000000  2.000000e+00      2.000000
# mean                                  88.388060  1.571338e+11   5462.427828
# std                                   47.964303  1.966943e+11   6086.404541
# min                                    3.000000  1.804995e+10   1158.689904
# 25%                                   47.000000  8.759188e+10   3310.558866
# 50%                                   89.000000  1.571338e+11   5462.427828
# 75%                                  124.000000  2.266757e+11   7614.296790
# max                                  178.000000  2.962176e+11   9766.165752
#
#        BRI GDP growth rate  BRI Y.o.Y. GDP growth rate p.c.  ...  \
# count             2.000000                         2.000000  ...
# mean              0.059942                         0.043939  ...
# std               0.014734                         0.013096  ...
# min               0.049524                         0.034679  ...
# 25%               0.054733                         0.039309  ...
# 50%               0.059942                         0.043939  ...
# 75%               0.065152                         0.048569  ...
# max               0.070361                         0.053200  ...
#
#        WITS Time to Export   IMF Financial Soundness Indicators  \
# count              5.000000                            5.000000
# mean              14.600000                           18.186000
# std                6.348228                            3.066615
# min                9.000000                           13.650000
# 25%               10.000000                           17.080000
# 50%               11.000000                           18.910000
# 75%               21.000000                           19.380000
# max               22.000000                           21.910000
#
#        WB Central Government Debt  BRI Internet penetration rate (%)  \
# count                         0.0                           2.000000
# mean                          NaN                           0.382500
# std                           NaN                           0.413657
# min                           NaN                           0.090000
# 25%                           NaN                           0.236250
# 50%                           NaN                           0.382500
# 75%                           NaN                           0.528750
# max                           NaN                           0.675000
#
#        BRI Population density (/km2)  \
# count                       2.000000
# mean                       90.283916
# std                         2.876320
# min                        88.250051
# 25%                        89.266984
# 50%                        90.283916
# 75%                        91.300849
# max                        92.317781
#
#        BRI Percentage of Urban Population in Total Population  \
# count                                           2.000000
# mean                                            0.477140
# std                                             0.381710
# min                                             0.207230
# 25%                                             0.342185
# 50%                                             0.477140
# 75%                                             0.612095
# max                                             0.747050
#
#        WB Cost of Starting a Business  \
# count                        2.000000
# mean                        28.350000
# std                         32.456201
# min                          5.400000
# 25%                         16.875000
# 50%                         28.350000
# 75%                         39.825000
# max                         51.300000
#
#        WB Ease of Doing Business Index (1 = most business-friendly regulations)  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        WB Logistics Performance Index (LPI) (range: 1-5)   \
# count                                           3.000000
# mean                                            3.333333
# std                                             0.815925
# min                                             2.580000
# 25%                                             2.900000
# 50%                                             3.220000
# 75%                                             3.710000
# max                                             4.200000
#
#        ED National Electric Power Consumption TwH
# count                                         1.0
# mean                                        149.0
# std                                           NaN
# min                                         149.0
# 25%                                         149.0
# 50%                                         149.0
# 75%                                         149.0
# max                                         149.0
#
# [8 rows x 26 columns]
